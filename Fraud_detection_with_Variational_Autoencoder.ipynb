# %% [markdown]
# Here, we will train an Variational Autoencoder Neural Network (implemented in Keras) in purely unsupervised fashion for Anomaly Detection in credit card transaction data. The brief work plan is given below for building the VAE model:
#
# * Scale the input features.
# * Create, and train variational autoencoder, that decode the data into a 2 dimentional latent space.
# * View the data in the latent 2D space, and check classification strategies.
#
# Reference: https://wiseodd.github.io/techblog/2016/12/10/variational-autoencoder/
#
# Difference between AE & VAE: https://blog.keras.io/building-autoencoders-in-keras.html
#
# An intuitive understanding of variational autoencoders: https://hsaghir.github.io/data_science/denoising-vs-variational-autoencoder/

# %% [markdown]
# #### Why VAE?
#
# VAE is a framework that was proposed as a scalable way to do variational EM (or variational inference in general) on large datasets. Although it has an AE like structure, it serves a much larger purpose.
#
# Having said that, one can, of course, use VAEs to learn latent representations. VAEs are known to give representations with disentangled factors [1] This happens due to isotropic Gaussian priors on the latent variables. Modeling them as Gaussians allows each dimension in the representation to push themselves as farther as possible from the other factors. Also, [1] added a regularization coefficient that controls the influence of the prior.
#
# While isotropic Gaussians are sufficient for most cases, for specific cases, one may want to model priors differently. For example, in the case of sequences, one may want to define priors as sequential models [2].
#
# Now, as one can see, prior gives significant control over how we want to model our latent distribution. This kind of control does not exist in the usual AE framework. This is actually the power of Bayesian models themselves, VAEs are simply making it more practical and feasible for large-scale datasets. So, to conclude, if you want precise control over your latent representations and what you would like them to represent, then choose VAE. Sometimes, precise modeling can capture better representations as in [2]. However, if AE suffices for the work you do, then just go with AE, it is simple and uncomplicated enough. After all, with AEs we are simply doing non-linear PCA.
#
# [1] Early Visual Concept Learning with Unsupervised Deep Learning, 2016
# Irina Higgins, Loic Matthey, Xavier Glorot, Arka Pal, Benigno Uria, Charles Blundell, Shakir Mohamed, Alexander Lerchner
# https://arxiv.org/abs/1606.05579
#
# [2] A Recurrent Latent Variable Model for Sequential Data, 2015
# Junyoung Chung, Kyle Kastner, Laurent Dinh, Kratarth Goel, Aaron Courville, Yoshua Bengio
# https://arxiv.org/abs/1506.02216
#
# Choosing the distribution of the code in VAE allows for a better unsupervised representation learning where samples of the same class end up close to each other in the code space. Also this way, finding a semantic for the regions in the code space becomes easier. E.g, you would know from each area what class can be generated.
#
# If you need more in-depth analysis, have a look at Durk Kingma' thesis. It's a great source for variational inference.

# %% [markdown]
# #### Intuitive understanding of variational autoencoders:
#
# A typical autoencoder can usually encode and decode data very well with low reconstruction error, but a random latent code seems to have little to do with the training data. In other words the latent code does not learn the probability distribution of the data and therefore, if we are interested in generating more data like our dataset a typical autoencoder doesn’t seem to work as well. There is however another version of autoencoders, called “variational autoencoder - VAE” that are able to solve this problem since they explicitly define a probability distribution on the latent code. The neural network architecture is very similar to a regular autoencoder but the difference is that the hidden code comes from a probability distribution that is learned during the training.
# ![vae_semi_M1.png](attachment:vae_semi_M1.png)
# A variational autoencoder is essentially a graphical model similar to the figure above in the simplest case. We assume a local latent variable, Zi for each data point Xi. The inference and data generation in a VAE benefit from the power of deep neural networks and scalable optimization algorithms like SGD.
#
# As can be seen from the picture above, in a VAE, the encoder becomes a variational inference network that maps the data to the a distribution for the hidden variables, and the decoder becomes a generative network that maps the latent variables back to the data. Since the latent variable is actually a probability distribution, we need to sample the hidden code from its distribution to be able to generate data.
#
# ![VAE_inf_gen.jpg](attachment:VAE_inf_gen.jpg)
#
# In order to be able to use stochastic gradient descent with this autoencoder network, we need to be able to calculate gradients w.r.t. all the nodes in the network. However, latent variables, z, in a graphical model are random variables (distributions) which are not differentiable. Therefore, to make it differentiable, we treat the mean and variances of the distributions as simple deterministic parameters and multiply the variance by a sample from a normal noise generator to add randomness. By parameterizing the hidden distribution this way, we can back-propagate the gradient to the parameters of the encoder and train the whole network with stochastic gradient descent. This procedure will allow us to learn mean and variance values for the hidden code and it’s called the “re-parameterization trick”. It is important to appreciate the importance of the fact that the whole network is now differentiable. This means that optimization techniques can now be used to solve the inference problem efficiently.
#
# In classic version of neural networks we could simply measure the error of network outputs with desired target value using a simple mean square error. But now that we are dealing with distributions, MSE is no longer a good error metric. So instead, loosely speaking, we use another metric for measuring the difference between two distributions i.e. KL-Divergence. It turns out that this distance between our variational approximate and the real posterior distribution is not very easy to minimize either. However, using some simple math, we can show that this distance is always positive and that it comprises of two main parts (probability of data minus a function called ELBO). So instead of minimizing the whole thing, we can maximize the smaller term (ELBO). This term comes from marginalizing the log-probability of data and is always smaller than the log probability of the data. That’s why we call it a lower bound on the evidence (data given model). From the perspective of autoencoders, the ELBO function can be seen as the sum of the reconstruction cost of the input plus the regularization terms.
#
# If after maximizing the ELBO, the lower bound of data is close to the data distribution, then the distance is close to zero and voila!; We have minimized the error distance indirectly. The algorithm we use to maximize the lower bound is the exact opposite of gradient descent. Instead of going in the reverse direction of the gradient to get to the minimum, we go toward the positive direction to get to the maximum, so it’s now called gradient ascent! This whole algorithm is called “autoencoding variational Bayes”! After we are done with the learning we can visualize the latent space of our VAE and generate samples from it. Pretty cool, eh!?
#
# ![vae_structure.jpg](attachment:vae_structure.jpg)

# %% [markdown]
# #### Import Keras and other necessary libraries:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import SVG

from sklearn import preprocessing, metrics, neighbors, datasets
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

from keras import backend as K
from keras.models import Model, load_model
from keras.layers import Input, Dense, Lambda, BatchNormalization, Dropout
from keras.optimizers import Adam, RMSprop
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, Callback, ModelCheckpoint, TensorBoard
from keras.utils.vis_utils import model_to_dot, plot_model, pydot

from sklearn.model_selection import train_test_split, StratifiedShuffleSplit

from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc, cohen_kappa_score,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support, accuracy_score, log_loss)

from matplotlib.colors import ListedColormap
# Out:
# C:\Users\sushant_singh01\AppData\Local\Continuum\anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
np.random.seed(42)

# %% [markdown]
# #### Read data set:

# %%
#read the dataset
csv = pd.read_csv("C:/Users/sushant_singh01/Documents/Python Scripts/Data/creditcard.csv")
csv.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...         V21       V22       V23       V24  \
# 0  0.098698  0.363787  ...   -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425  ...   -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  ...    0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024  ...   -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  ...   -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28  Amount  Class
# 0  0.128539 -0.189115  0.133558 -0.021053  149.62      0
# 1  0.167170  0.125895 -0.008983  0.014724    2.69      0
# 2 -0.327642 -0.139097 -0.055353 -0.059752  378.66      0
# 3  0.647376 -0.221929  0.062723  0.061458  123.50      0
# 4 -0.206010  0.502292  0.219422  0.215153   69.99      0
#
# [5 rows x 31 columns]

# %% [markdown]
# #### Prepare training, validation and test datasets:

# %%
data = csv.astype('float32').copy()
data.sort_values('Time', inplace=True)

# %%
# Applying Standard Scalar on Amount attribute
#scaler = preprocessing.StandardScaler()
#data['Amount'] = scaler.fit_transform(data['Amount'].values.reshape(-1, 1))
#data['Amount'].head()

# %%
#x_train, x_test, y_train, y_test = train_test_split(data.iloc[:,1:-1], data['Class'], test_size=0.3, random_state=42)
#x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42)

# %%
data.iloc[:,1:-1].head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10     ...           V20       V21       V22  \
# 0  0.098698  0.363787  0.090794     ...      0.251412 -0.018307  0.277838
# 1  0.085102 -0.255425 -0.166974     ...     -0.069083 -0.225775 -0.638672
# 2  0.247676 -1.514654  0.207643     ...      0.524980  0.247998  0.771679
# 3  0.377436 -1.387024 -0.054952     ...     -0.208038 -0.108300  0.005274
# 4 -0.270533  0.817739  0.753074     ...      0.408542 -0.009431  0.798279
#
#         V23       V24       V25       V26       V27       V28      Amount
# 0 -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.619995
# 1  0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.690000
# 2  0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.660004
# 3 -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.500000
# 4 -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.989998
#
# [5 rows x 29 columns]

# %%
# Here the stratified shuffle split is done
X = data.iloc[:,1:-1]
Y = data['Class']

# have used 50 splits and test data proportion equal to 0.2
sss= StratifiedShuffleSplit(n_splits=50, test_size=0.2, random_state=42)

# equating the index of all the shuffled index to the data.
for train_index, test_index in sss.split(X, Y):                           
        x_train, x_test = X.iloc[train_index], X.iloc[test_index]            
        y_train, y_test = Y.iloc[train_index], Y.iloc[test_index]

# %%
#Applying Standard Scaler to bring all the train & test input atrributes under single scale
scaler = preprocessing.StandardScaler()
x_train, x_test = scaler.fit_transform(x_train), scaler.fit_transform(x_test)

# %%
print ('Input Shape: ', data.shape)
# Out:
# Input Shape:  (284807, 31)

# %%
print ('train Shape: ', x_train.shape, y_train.shape)
print ('test Shape: ', x_test.shape, y_test.shape)
# Out:
# train Shape:  (227845, 29) (227845,)
# test Shape:  (56962, 29) (56962,)

# %% [markdown]
# ### Building the VAE model:

# %% [markdown]
# #### First, let’s implement the encoder net Q(z|X), which takes input X and outputting two things: μ(X) and Σ(X), the parameters of the Gaussian.

# %% [markdown]
# That is, our Q(z|X) is a neural net with one hidden layer. In this implementation, our latent variable is two dimensional, so that we could easily visualize it. In practice though, more dimension in latent variable should be better.

# %% [markdown]
# ![IN.PNG](attachment:IN.PNG)

# %%
hidden_size = 16 #size of the hidden layer in encoder and decoder
latent_dim = 2 #number of latent variables to learn

input_dim = x_train.shape[1]

# input layer
input_layer = Input(shape=(input_dim,))

# hidden layer
encoder_hidden = Dense(hidden_size, activation='relu' , name='encoder_hidden')(input_layer)
#encoder_hidden = BatchNormalization()(input_layer)
#encoder_hidden = Dense(hidden_size, activation='relu' , name='encoder_hidden')(encoder_hidden)
#encoder_hidden = BatchNormalization()(encoder_hidden)

# output layer for mean and log variance
z_mean = Dense(latent_dim, name='z_mean')(encoder_hidden)
z_log_var = Dense(latent_dim, name='z_log_var')(encoder_hidden)

# %% [markdown]
# However, we are now facing a problem. How do we get z from the encoder outputs? Obviously we could sample z from a Gaussian which parameters are the outputs of the encoder. Alas, sampling directly won’t do, if we want to train VAE with gradient descent as the sampling operation doesn’t have gradient!
#
# There is, however a trick called reparameterization trick, which makes the network differentiable. Reparameterization trick basically divert the non-differentiable operation out of the network, so that, even though we still involve a thing that is non-differentiable, at least it is out of the network, hence the network could still be trained.
#
# The reparameterization trick is as follows.
# Recall, if we have x∼N(μ,Σ) and then standardize it so that μ=0,Σ=1 we could revert it back to the original distribution by reverting the standardization process. Hence, we have this equation:
# x=μ+Σpow(1/2)xstd
#
# With that in mind, we could extend it. If we sample from a standard normal distribution, we could convert it to any Gaussian we want if we know the mean and the variance. Hence we could implement our sampling operation of z by:
#
# z=μ(X)+Σpow(1/2)(X)ϵ
# where ϵ∼N(0,1).
#
# Now, during backpropagation, we don’t care anymore with the sampling process, as it is now outside of the network, i.e. doesn’t depend on anything in the net, hence the gradient won’t flow through it.

# %% [markdown]
# ![RP.PNG](attachment:RP.PNG)

# %%
def sampling(args):
    z_mean, z_log_var = args
    epsilon = K.random_normal(shape=K.shape(z_mean), mean=0., stddev=1.)
    return z_mean + K.exp(z_log_var / 2) * epsilon

# Sample z ~ Q(z|X)
z = Lambda(sampling, name='z_sampled')([z_mean, z_log_var])

# %% [markdown]
# Now we create the decoder net P(X|z):

# %%
# P(X|z) -- decoder
decoder_hidden = Dense(hidden_size, activation='relu', name='decoder_hidden')
decoded_mean = Dense(input_dim, activation=None, name='decoded_mean')

# %% [markdown]
# Define a separate Decoder model, that reconstruct data from latent variable.
# The decoder model uses weights that was trained with the VAE model.
# We need a separate model, if we want to generate data from given data in latent space.

# %%
# Generator model, generate new data given latent variable z
d_in = Input(shape=(latent_dim,), name='decoder_input')
d_h = decoder_hidden(d_in)
d_out = decoded_mean(d_h)
decoder = Model(d_in, d_out, name='decoder')

# %% [markdown]
# Now create the output layer

# %%
h_p = decoder_hidden(z)
output_layer = decoded_mean(h_p)

# %% [markdown]
# Lastly, from this model, we can do three things: reconstruct inputs, encode inputs into latent variables, and generate data from latent variable. So, we have three Keras models:

# %%
# Overall VAE model, for reconstruction and training
vae = Model(input_layer, output_layer)

# Encoder model, to encode input into latent variable. We use the mean as the output as it is the center point, 
#the representative of the gaussian.
encoder = Model(input_layer, z_mean)

# %% [markdown]
# ![VAE.PNG](attachment:VAE.PNG)

# %% [markdown]
# Then, we need to translate our loss into Keras code. Calculate VAE loss = reconstruction loss + KL loss for each data in minibatch.

# %%
def rec_loss(y_true, y_pred):
    return K.sum(K.square(y_true - y_pred), axis=-1)

def kl_loss(y_true, y_pred):
    return - 0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)

def vae_loss(y_true, y_pred):
    rec_loss = K.sum(K.square(y_true - y_pred), axis=-1)
    kl_loss = - 0.5 * K.sum(1 + z_log_var - K.square(z_mean) - K.exp(z_log_var), axis=-1)
    return K.mean((rec_loss + kl_loss) / 2)

# %% [markdown]
# Now, compile your model & print the summary

# %%
#vae.compile(optimizer=Adam(lr=1e-2), loss=vae_loss, metrics=[rec_loss, kl_loss, 'accuracy'])
#vae.compile(optimizer=Adam(lr=1e-2, decay=1e-5), loss=vae_loss, metrics=[rec_loss, kl_loss])
#vae.compile(optimizer=RMSprop(lr=1e-2, decay=1e-5), loss=vae_loss, metrics=[rec_loss, kl_loss])
vae.compile(optimizer=Adam(), loss=vae_loss, metrics=[rec_loss, kl_loss])
vae.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 29)           0
# __________________________________________________________________________________________________
# encoder_hidden (Dense)          (None, 16)           480         input_1[0][0]
# __________________________________________________________________________________________________
# z_mean (Dense)                  (None, 2)            34          encoder_hidden[0][0]
# __________________________________________________________________________________________________
# z_log_var (Dense)               (None, 2)            34          encoder_hidden[0][0]
# __________________________________________________________________________________________________
# z_sampled (Lambda)              (None, 2)            0           z_mean[0][0]
#                                                                  z_log_var[0][0]
# __________________________________________________________________________________________________
# decoder_hidden (Dense)          (None, 16)           48          z_sampled[0][0]
# __________________________________________________________________________________________________
# decoded_mean (Dense)            (None, 29)           493         decoder_hidden[1][0]
# ==================================================================================================
# Total params: 1,089
# Trainable params: 1,089
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Define a class to save best VAE, encoder and decoder models

# %%
#Checkpoint to save best model
vlos = float(10000.)

class SaveBest(Callback):
    global vlos
    vlos = float(10000.)

    def on_epoch_end(self, batch, logs={}):
        global vlos
        tmp = logs.get('val_loss')
        if (tmp==None):
            tmp = 1000.
        
        if (vlos - float(tmp) > 0.000001) :
            print ('loss improved from: ', vlos, ' to: ', tmp, 'saving models')
            vlos = float(tmp)
            encoder.save('best_encoder.h5')
            decoder.save('best_decoder.h5')
            vae.save('best_vae.h5')

#Create the object so that it can be used in callbacks            
savebest = SaveBest()

# %% [markdown]
# Plot Model Visualization to validate

# %%
import os
os.environ["PATH"] += os.pathsep + 'C:/Users/sushant_singh01/graphviz-2.38/release/bin/'

# %%
#SVG(model_to_dot(vae, show_shapes='true').create(prog='pydotplus', format='svg'))
plot_model(vae, to_file='vae_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ![vae_plot.png](attachment:vae_plot.png)

# %% [markdown]
# Train the model with early stopping and a kind of learning rate schedule for the specified number of epochs with the specified batch size:

# %%
n_epochs = 200
batch_size = 32

#Checkpoint to save best model
#checkpointer = ModelCheckpoint(filepath="VAEmodel.h5", verbose=0, save_best_only=True)

#Save tensorboard events
tensorboard = TensorBoard(log_dir='C:/tmp/Anamoly/VAE/',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)

#stop training if loss does not decrease with at least 0.00001
early_stopping = EarlyStopping(monitor='loss', patience=10, min_delta=1e-5) 

#reduce learning rate (divide it by 5 = multiply it by 0.2) if loss does not decrease with at least 0.00001
reduce_lr = ReduceLROnPlateau(monitor='loss', patience=5, min_delta=1e-5, factor=0.2) 

callbacks = [early_stopping, reduce_lr, savebest, tensorboard]

#collect training data in history object
history = vae.fit(x_train, x_train, 
                  validation_data=(x_test, x_test), 
                  batch_size=batch_size, 
                  shuffle=True,
                  epochs=n_epochs,
                  callbacks=callbacks)
# Out:
# Train on 227845 samples, validate on 56962 samples
# Epoch 1/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 13.1838 - rec_loss: 25.1236 - kl_loss: 1.2440 - val_loss: 12.5218 - val_rec_loss: 23.6163 - val_kl_loss: 1.4273
# loss improved from:  10000.0  to:  12.521794192045368 saving models
# Epoch 2/200
# 227845/227845 [==============================] - 10s 45us/step - loss: 12.2512 - rec_loss: 22.9643 - kl_loss: 1.5382 - val_loss: 12.0454 - val_rec_loss: 22.5627 - val_kl_loss: 1.5282
# loss improved from:  12.521794192045368  to:  12.045420829392832 saving models
# Epoch 3/200
# 227845/227845 [==============================] - 12s 52us/step - loss: 11.9963 - rec_loss: 22.4061 - kl_loss: 1.5866 - val_loss: 11.8886 - val_rec_loss: 22.1446 - val_kl_loss: 1.6326
# loss improved from:  12.045420829392832  to:  11.88855841263539 saving models
# Epoch 4/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 11.9065 - rec_loss: 22.1606 - kl_loss: 1.6525 - val_loss: 11.7346 - val_rec_loss: 21.8091 - val_kl_loss: 1.6602
# loss improved from:  11.88855841263539  to:  11.734633705881446 saving models
# Epoch 5/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 11.8077 - rec_loss: 21.8606 - kl_loss: 1.7548 - val_loss: 11.6446 - val_rec_loss: 21.5281 - val_kl_loss: 1.7611
# loss improved from:  11.734633705881446  to:  11.644573146743321 saving models
# Epoch 6/200
# 227845/227845 [==============================] - 10s 46us/step - loss: 11.7348 - rec_loss: 21.6259 - kl_loss: 1.8436 - val_loss: 11.5524 - val_rec_loss: 21.2648 - val_kl_loss: 1.8400
# loss improved from:  11.644573146743321  to:  11.552412274655556 saving models
# Epoch 7/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 11.6763 - rec_loss: 21.4389 - kl_loss: 1.9136 - val_loss: 11.4566 - val_rec_loss: 20.9608 - val_kl_loss: 1.9524
# loss improved from:  11.552412274655556  to:  11.45663126802215 saving models
# Epoch 8/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 11.6294 - rec_loss: 21.3037 - kl_loss: 1.9551 - val_loss: 11.4131 - val_rec_loss: 20.8382 - val_kl_loss: 1.9881
# loss improved from:  11.45663126802215  to:  11.413144181448649 saving models
# Epoch 9/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 11.5826 - rec_loss: 21.1880 - kl_loss: 1.9772 - val_loss: 11.3593 - val_rec_loss: 20.7010 - val_kl_loss: 2.0175
# loss improved from:  11.413144181448649  to:  11.3592583548926 saving models
# Epoch 10/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 11.5428 - rec_loss: 21.0821 - kl_loss: 2.0035 - val_loss: 11.3930 - val_rec_loss: 20.7587 - val_kl_loss: 2.0272
# Epoch 11/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 11.4933 - rec_loss: 20.9511 - kl_loss: 2.0355 - val_loss: 11.3561 - val_rec_loss: 20.7391 - val_kl_loss: 1.9730
# loss improved from:  11.3592583548926  to:  11.356066641481585 saving models
# Epoch 12/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 11.4547 - rec_loss: 20.8579 - kl_loss: 2.0515 - val_loss: 11.3293 - val_rec_loss: 20.5498 - val_kl_loss: 2.1088
# loss improved from:  11.356066641481585  to:  11.329310843500963 saving models
# Epoch 13/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 11.4227 - rec_loss: 20.7713 - kl_loss: 2.0741 - val_loss: 11.3093 - val_rec_loss: 20.5182 - val_kl_loss: 2.1004
# loss improved from:  11.329310843500963  to:  11.309326040297345 saving models
# Epoch 14/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 11.3851 - rec_loss: 20.6720 - kl_loss: 2.0983 - val_loss: 11.3015 - val_rec_loss: 20.5005 - val_kl_loss: 2.1024
# loss improved from:  11.309326040297345  to:  11.301492415830278 saving models
# Epoch 15/200
# 227845/227845 [==============================] - 11s 50us/step - loss: 11.3670 - rec_loss: 20.6250 - kl_loss: 2.1091 - val_loss: 11.2952 - val_rec_loss: 20.4719 - val_kl_loss: 2.1186
# loss improved from:  11.301492415830278  to:  11.295245023629441 saving models
# Epoch 16/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 11.3474 - rec_loss: 20.5692 - kl_loss: 2.1256 - val_loss: 11.2549 - val_rec_loss: 20.2694 - val_kl_loss: 2.2404
# loss improved from:  11.295245023629441  to:  11.254866818540247 saving models
# Epoch 17/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 11.3290 - rec_loss: 20.5197 - kl_loss: 2.1383 - val_loss: 11.2386 - val_rec_loss: 20.2993 - val_kl_loss: 2.1780
# loss improved from:  11.254866818540247  to:  11.238648192408146 saving models
# Epoch 18/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 11.3113 - rec_loss: 20.4750 - kl_loss: 2.1476 - val_loss: 11.2035 - val_rec_loss: 20.2835 - val_kl_loss: 2.1235
# loss improved from:  11.238648192408146  to:  11.203490515211644 saving models
# Epoch 19/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 11.2887 - rec_loss: 20.4343 - kl_loss: 2.1431 - val_loss: 11.2266 - val_rec_loss: 20.3260 - val_kl_loss: 2.1272
# Epoch 20/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 11.2897 - rec_loss: 20.4153 - kl_loss: 2.1641 - val_loss: 11.2143 - val_rec_loss: 20.2621 - val_kl_loss: 2.1665
# Epoch 21/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 11.2737 - rec_loss: 20.3807 - kl_loss: 2.1668 - val_loss: 11.2095 - val_rec_loss: 20.2881 - val_kl_loss: 2.1309
# Epoch 22/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 11.2654 - rec_loss: 20.3572 - kl_loss: 2.1737 - val_loss: 11.1797 - val_rec_loss: 20.1404 - val_kl_loss: 2.2191
# loss improved from:  11.203490515211644  to:  11.179742125002237 saving models
# Epoch 23/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 11.2530 - rec_loss: 20.3271 - kl_loss: 2.1790 - val_loss: 11.1764 - val_rec_loss: 20.1190 - val_kl_loss: 2.2337
# loss improved from:  11.179742125002237  to:  11.176369222913756 saving models
# Epoch 24/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 11.2463 - rec_loss: 20.3076 - kl_loss: 2.1850 - val_loss: 11.1756 - val_rec_loss: 20.0818 - val_kl_loss: 2.2695
# loss improved from:  11.176369222913756  to:  11.175632093876986 saving models
# Epoch 25/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 11.2385 - rec_loss: 20.2914 - kl_loss: 2.1856 - val_loss: 11.1975 - val_rec_loss: 20.2383 - val_kl_loss: 2.1567
# Epoch 26/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 11.2323 - rec_loss: 20.2697 - kl_loss: 2.1950 - val_loss: 11.2004 - val_rec_loss: 20.2183 - val_kl_loss: 2.1826
# Epoch 27/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 11.2240 - rec_loss: 20.2620 - kl_loss: 2.1860 - val_loss: 11.2315 - val_rec_loss: 20.2777 - val_kl_loss: 2.1854
# Epoch 28/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 11.2143 - rec_loss: 20.2251 - kl_loss: 2.2035 - val_loss: 11.1664 - val_rec_loss: 20.1299 - val_kl_loss: 2.2029
# loss improved from:  11.175632093876986  to:  11.166382143024581 saving models
# Epoch 29/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 11.2152 - rec_loss: 20.2308 - kl_loss: 2.1995 - val_loss: 11.1247 - val_rec_loss: 20.0189 - val_kl_loss: 2.2305
# loss improved from:  11.166382143024581  to:  11.124687114963496 saving models
# Epoch 30/200
# 227845/227845 [==============================] - 12s 55us/step - loss: 11.2046 - rec_loss: 20.2025 - kl_loss: 2.2067 - val_loss: 11.1752 - val_rec_loss: 20.1724 - val_kl_loss: 2.1779
# Epoch 31/200
# 227845/227845 [==============================] - 12s 51us/step - loss: 11.2104 - rec_loss: 20.2175 - kl_loss: 2.2032 - val_loss: 11.1174 - val_rec_loss: 20.0355 - val_kl_loss: 2.1993
# loss improved from:  11.124687114963496  to:  11.117392228069166 saving models
# Epoch 32/200
# 227845/227845 [==============================] - 12s 53us/step - loss: 11.1841 - rec_loss: 20.1670 - kl_loss: 2.2013 - val_loss: 11.1523 - val_rec_loss: 20.0962 - val_kl_loss: 2.2084
# Epoch 33/200
# 227845/227845 [==============================] - 12s 51us/step - loss: 11.1866 - rec_loss: 20.1635 - kl_loss: 2.2097 - val_loss: 11.1134 - val_rec_loss: 20.0233 - val_kl_loss: 2.2035
# loss improved from:  11.117392228069166  to:  11.113418862665727 saving models
# Epoch 34/200
# 227845/227845 [==============================] - 11s 50us/step - loss: 11.1787 - rec_loss: 20.1391 - kl_loss: 2.2184 - val_loss: 11.1051 - val_rec_loss: 19.9291 - val_kl_loss: 2.2810
# loss improved from:  11.113418862665727  to:  11.105051800514984 saving models
# Epoch 35/200
# 227845/227845 [==============================] - 12s 51us/step - loss: 11.1905 - rec_loss: 20.1600 - kl_loss: 2.2210 - val_loss: 11.1360 - val_rec_loss: 20.0869 - val_kl_loss: 2.1850
# Epoch 36/200
# 227845/227845 [==============================] - 10s 46us/step - loss: 11.1867 - rec_loss: 20.1543 - kl_loss: 2.2192 - val_loss: 11.0856 - val_rec_loss: 19.9573 - val_kl_loss: 2.2140
# loss improved from:  11.105051800514984  to:  11.085640446104481 saving models
# Epoch 37/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 11.1902 - rec_loss: 20.1588 - kl_loss: 2.2216 - val_loss: 11.1675 - val_rec_loss: 20.0506 - val_kl_loss: 2.2843
# Epoch 38/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 11.1714 - rec_loss: 20.1186 - kl_loss: 2.2243 - val_loss: 11.0652 - val_rec_loss: 19.8885 - val_kl_loss: 2.2418
# loss improved from:  11.085640446104481  to:  11.065165595958744 saving models
# Epoch 39/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 11.1756 - rec_loss: 20.1183 - kl_loss: 2.2329 - val_loss: 11.1380 - val_rec_loss: 20.0575 - val_kl_loss: 2.2184
# Epoch 40/200
# 227845/227845 [==============================] - 11s 46us/step - loss: 11.1726 - rec_loss: 20.1110 - kl_loss: 2.2343 - val_loss: 11.0760 - val_rec_loss: 19.9073 - val_kl_loss: 2.2448
# Epoch 41/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 11.1658 - rec_loss: 20.0941 - kl_loss: 2.2376 - val_loss: 11.0628 - val_rec_loss: 19.9440 - val_kl_loss: 2.1817
# loss improved from:  11.065165595958744  to:  11.062826995706295 saving models
# Epoch 42/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 11.1604 - rec_loss: 20.0909 - kl_loss: 2.2300 - val_loss: 11.0435 - val_rec_loss: 19.8389 - val_kl_loss: 2.2481
# loss improved from:  11.062826995706295  to:  11.043535196614991 saving models
# Epoch 43/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 11.1653 - rec_loss: 20.0958 - kl_loss: 2.2349 - val_loss: 11.0996 - val_rec_loss: 20.0191 - val_kl_loss: 2.1802
# Epoch 44/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 11.1580 - rec_loss: 20.0799 - kl_loss: 2.2361 - val_loss: 11.0228 - val_rec_loss: 19.8395 - val_kl_loss: 2.2061
# loss improved from:  11.043535196614991  to:  11.022766637298181 saving models
# Epoch 45/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 11.1599 - rec_loss: 20.0773 - kl_loss: 2.2424 - val_loss: 11.0638 - val_rec_loss: 19.8948 - val_kl_loss: 2.2329
# Epoch 46/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 11.1539 - rec_loss: 20.0674 - kl_loss: 2.2404 - val_loss: 11.1538 - val_rec_loss: 20.1392 - val_kl_loss: 2.1684
# Epoch 47/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 11.1520 - rec_loss: 20.0616 - kl_loss: 2.2425 - val_loss: 11.0783 - val_rec_loss: 19.9025 - val_kl_loss: 2.2540
# Epoch 48/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 11.1454 - rec_loss: 20.0384 - kl_loss: 2.2523 - val_loss: 11.0822 - val_rec_loss: 19.9084 - val_kl_loss: 2.2561
# Epoch 49/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 11.1441 - rec_loss: 20.0312 - kl_loss: 2.2571 - val_loss: 11.0409 - val_rec_loss: 19.8033 - val_kl_loss: 2.2784
# Epoch 50/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 11.1348 - rec_loss: 20.0102 - kl_loss: 2.2593 - val_loss: 11.0234 - val_rec_loss: 19.7651 - val_kl_loss: 2.2818
# Epoch 51/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 11.1401 - rec_loss: 20.0170 - kl_loss: 2.2633 - val_loss: 11.0522 - val_rec_loss: 19.8928 - val_kl_loss: 2.2117
# Epoch 52/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 11.1336 - rec_loss: 19.9955 - kl_loss: 2.2717 - val_loss: 11.1128 - val_rec_loss: 19.9946 - val_kl_loss: 2.2310
# Epoch 53/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 11.1277 - rec_loss: 19.9863 - kl_loss: 2.2691 - val_loss: 11.0261 - val_rec_loss: 19.8340 - val_kl_loss: 2.2183
# Epoch 54/200
# 227845/227845 [==============================] - 11s 46us/step - loss: 11.1284 - rec_loss: 19.9795 - kl_loss: 2.2773 - val_loss: 11.0190 - val_rec_loss: 19.7097 - val_kl_loss: 2.3283
# loss improved from:  11.022766637298181  to:  11.019010285121379 saving models
# Epoch 55/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 11.1267 - rec_loss: 19.9745 - kl_loss: 2.2788 - val_loss: 10.9787 - val_rec_loss: 19.6535 - val_kl_loss: 2.3039
# loss improved from:  11.019010285121379  to:  10.978696270423644 saving models
# Epoch 56/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 11.1271 - rec_loss: 19.9690 - kl_loss: 2.2851 - val_loss: 10.9936 - val_rec_loss: 19.7201 - val_kl_loss: 2.2671
# Epoch 57/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 11.1222 - rec_loss: 19.9538 - kl_loss: 2.2905 - val_loss: 11.0652 - val_rec_loss: 19.8590 - val_kl_loss: 2.2715
# Epoch 58/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 11.1146 - rec_loss: 19.9361 - kl_loss: 2.2931 - val_loss: 10.9908 - val_rec_loss: 19.7048 - val_kl_loss: 2.2769
# Epoch 59/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 11.1203 - rec_loss: 19.9548 - kl_loss: 2.2859 - val_loss: 10.9827 - val_rec_loss: 19.7095 - val_kl_loss: 2.2559
# Epoch 60/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 11.1186 - rec_loss: 19.9398 - kl_loss: 2.2974 - val_loss: 10.9945 - val_rec_loss: 19.6935 - val_kl_loss: 2.2955
# Epoch 61/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 11.1171 - rec_loss: 19.9385 - kl_loss: 2.2956 - val_loss: 11.0149 - val_rec_loss: 19.7377 - val_kl_loss: 2.2922
# Epoch 62/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 11.1227 - rec_loss: 19.9462 - kl_loss: 2.2992 - val_loss: 10.9612 - val_rec_loss: 19.6789 - val_kl_loss: 2.2435
# loss improved from:  10.978696270423644  to:  10.961237549861325 saving models
# Epoch 63/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 11.0999 - rec_loss: 19.9095 - kl_loss: 2.2902 - val_loss: 11.0266 - val_rec_loss: 19.7813 - val_kl_loss: 2.2720
# Epoch 64/200
# 227845/227845 [==============================] - 12s 51us/step - loss: 11.1044 - rec_loss: 19.9129 - kl_loss: 2.2958 - val_loss: 11.0002 - val_rec_loss: 19.7240 - val_kl_loss: 2.2765
# Epoch 65/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 11.1027 - rec_loss: 19.9063 - kl_loss: 2.2991 - val_loss: 11.0487 - val_rec_loss: 19.8373 - val_kl_loss: 2.2600
# Epoch 66/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 11.0998 - rec_loss: 19.8929 - kl_loss: 2.3068 - val_loss: 11.0033 - val_rec_loss: 19.7506 - val_kl_loss: 2.2560
# Epoch 67/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 11.0938 - rec_loss: 19.8767 - kl_loss: 2.3109 - val_loss: 10.9456 - val_rec_loss: 19.6169 - val_kl_loss: 2.2744
# loss improved from:  10.961237549861325  to:  10.94561095512473 saving models
# Epoch 68/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 11.0916 - rec_loss: 19.8682 - kl_loss: 2.3149 - val_loss: 11.0297 - val_rec_loss: 19.7284 - val_kl_loss: 2.3310
# Epoch 69/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 11.0887 - rec_loss: 19.8645 - kl_loss: 2.3130 - val_loss: 10.9185 - val_rec_loss: 19.4873 - val_kl_loss: 2.3496
# loss improved from:  10.94561095512473  to:  10.918471448370665 saving models
# Epoch 70/200
# 227845/227845 [==============================] - 12s 51us/step - loss: 11.0919 - rec_loss: 19.8757 - kl_loss: 2.3081 - val_loss: 10.9687 - val_rec_loss: 19.6454 - val_kl_loss: 2.2921
# Epoch 71/200
# 227845/227845 [==============================] - 11s 50us/step - loss: 11.0732 - rec_loss: 19.8340 - kl_loss: 2.3123 - val_loss: 10.9508 - val_rec_loss: 19.6384 - val_kl_loss: 2.2631
# Epoch 72/200
# 227845/227845 [==============================] - 9s 41us/step - loss: 11.0735 - rec_loss: 19.8455 - kl_loss: 2.3015 - val_loss: 11.1335 - val_rec_loss: 19.8800 - val_kl_loss: 2.3871
# Epoch 73/200
# 227845/227845 [==============================] - 11s 46us/step - loss: 11.0756 - rec_loss: 19.8445 - kl_loss: 2.3067 - val_loss: 10.8749 - val_rec_loss: 19.4156 - val_kl_loss: 2.3343
# loss improved from:  10.918471448370665  to:  10.874934697635874 saving models
# Epoch 74/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 11.0865 - rec_loss: 19.8594 - kl_loss: 2.3135 - val_loss: 10.8987 - val_rec_loss: 19.5066 - val_kl_loss: 2.2908
# Epoch 75/200
# 227845/227845 [==============================] - 13s 55us/step - loss: 11.0815 - rec_loss: 19.8574 - kl_loss: 2.3055 - val_loss: 10.9695 - val_rec_loss: 19.6090 - val_kl_loss: 2.3300
# Epoch 76/200
# 227845/227845 [==============================] - 14s 62us/step - loss: 11.0688 - rec_loss: 19.8206 - kl_loss: 2.3169 - val_loss: 10.9518 - val_rec_loss: 19.5237 - val_kl_loss: 2.3799
# Epoch 77/200
# 227845/227845 [==============================] - 11s 50us/step - loss: 11.0744 - rec_loss: 19.8443 - kl_loss: 2.3044 - val_loss: 10.8829 - val_rec_loss: 19.4329 - val_kl_loss: 2.3330
# Epoch 78/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 11.0732 - rec_loss: 19.8240 - kl_loss: 2.3225 - val_loss: 10.9112 - val_rec_loss: 19.4869 - val_kl_loss: 2.3355
# Epoch 79/200
# 227845/227845 [==============================] - 10s 44us/step - loss: 11.0678 - rec_loss: 19.8265 - kl_loss: 2.3092 - val_loss: 10.9366 - val_rec_loss: 19.5522 - val_kl_loss: 2.3209
# Epoch 80/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 11.0636 - rec_loss: 19.8206 - kl_loss: 2.3066 - val_loss: 10.9089 - val_rec_loss: 19.4955 - val_kl_loss: 2.3223
# Epoch 81/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 11.0660 - rec_loss: 19.8218 - kl_loss: 2.3103 - val_loss: 16619.2952 - val_rec_loss: 30774.1654 - val_kl_loss: 2464.4243
# Epoch 82/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 11.0656 - rec_loss: 19.8213 - kl_loss: 2.3100 - val_loss: 10.8419 - val_rec_loss: 19.3592 - val_kl_loss: 2.3247
# loss improved from:  10.874934697635874  to:  10.841910116768197 saving models
# Epoch 83/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 11.0598 - rec_loss: 19.8098 - kl_loss: 2.3097 - val_loss: 10.9207 - val_rec_loss: 19.5707 - val_kl_loss: 2.2706
# Epoch 84/200
# 227845/227845 [==============================] - 12s 54us/step - loss: 11.0826 - rec_loss: 19.8520 - kl_loss: 2.3133 - val_loss: 10.8630 - val_rec_loss: 19.3749 - val_kl_loss: 2.3511
# Epoch 85/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 11.0554 - rec_loss: 19.7880 - kl_loss: 2.3227 - val_loss: 10.8610 - val_rec_loss: 19.4146 - val_kl_loss: 2.3074
# Epoch 86/200
# 227845/227845 [==============================] - 9s 40us/step - loss: 11.0558 - rec_loss: 19.7984 - kl_loss: 2.3132 - val_loss: 10.8766 - val_rec_loss: 19.4862 - val_kl_loss: 2.2670
# Epoch 87/200
# 227845/227845 [==============================] - 12s 51us/step - loss: 11.0605 - rec_loss: 19.8182 - kl_loss: 2.3028 - val_loss: 10.8503 - val_rec_loss: 19.4101 - val_kl_loss: 2.2904
# Epoch 88/200
# 227845/227845 [==============================] - 13s 56us/step - loss: 11.0601 - rec_loss: 19.8117 - kl_loss: 2.3085 - val_loss: 11.3590 - val_rec_loss: 20.3414 - val_kl_loss: 2.3765
# Epoch 89/200
# 227845/227845 [==============================] - 13s 57us/step - loss: 11.0545 - rec_loss: 19.8015 - kl_loss: 2.3075 - val_loss: 11.1419 - val_rec_loss: 19.9435 - val_kl_loss: 2.3402
# Epoch 90/200
# 227845/227845 [==============================] - 11s 50us/step - loss: 11.0621 - rec_loss: 19.8260 - kl_loss: 2.2981 - val_loss: 10.8737 - val_rec_loss: 19.4746 - val_kl_loss: 2.2728
# Epoch 91/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 11.0610 - rec_loss: 19.8255 - kl_loss: 2.2964 - val_loss: 10.8544 - val_rec_loss: 19.4366 - val_kl_loss: 2.2723
# Epoch 92/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 11.0718 - rec_loss: 19.8498 - kl_loss: 2.2937 - val_loss: 10.9111 - val_rec_loss: 19.5263 - val_kl_loss: 2.2959
# Epoch 93/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 11.0454 - rec_loss: 19.7902 - kl_loss: 2.3007 - val_loss: 10.9465 - val_rec_loss: 19.5899 - val_kl_loss: 2.3031
# Epoch 94/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 11.0799 - rec_loss: 19.8595 - kl_loss: 2.3003 - val_loss: 10.8322 - val_rec_loss: 19.3779 - val_kl_loss: 2.2865
# loss improved from:  10.841910116768197  to:  10.832225505398513 saving models
# Epoch 95/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 11.0540 - rec_loss: 19.8089 - kl_loss: 2.2990 - val_loss: 10.8867 - val_rec_loss: 19.4806 - val_kl_loss: 2.2928
# Epoch 96/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 11.0639 - rec_loss: 19.8210 - kl_loss: 2.3069 - val_loss: 10.8423 - val_rec_loss: 19.3781 - val_kl_loss: 2.3065
# Epoch 97/200
# 227845/227845 [==============================] - 10s 45us/step - loss: 11.0523 - rec_loss: 19.8011 - kl_loss: 2.3035 - val_loss: 11.0140 - val_rec_loss: 19.7403 - val_kl_loss: 2.2878
# Epoch 98/200
# 227845/227845 [==============================] - 10s 44us/step - loss: 11.0595 - rec_loss: 19.8161 - kl_loss: 2.3029 - val_loss: 10.9020 - val_rec_loss: 19.5084 - val_kl_loss: 2.2955
# Epoch 99/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 10.9719 - rec_loss: 19.6459 - kl_loss: 2.2978 - val_loss: 10.7730 - val_rec_loss: 19.2482 - val_kl_loss: 2.2977
# loss improved from:  10.832225505398513  to:  10.772961545043279 saving models
# Epoch 100/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 10.9540 - rec_loss: 19.6079 - kl_loss: 2.3000 - val_loss: 10.7769 - val_rec_loss: 19.2686 - val_kl_loss: 2.2852
# Epoch 101/200
# 227845/227845 [==============================] - 10s 45us/step - loss: 10.9569 - rec_loss: 19.6098 - kl_loss: 2.3040 - val_loss: 10.7809 - val_rec_loss: 19.2515 - val_kl_loss: 2.3104
# Epoch 102/200
# 227845/227845 [==============================] - 10s 45us/step - loss: 10.9563 - rec_loss: 19.6076 - kl_loss: 2.3049 - val_loss: 10.7672 - val_rec_loss: 19.2282 - val_kl_loss: 2.3062
# loss improved from:  10.772961545043279  to:  10.767174955256673 saving models
# Epoch 103/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 10.9493 - rec_loss: 19.5992 - kl_loss: 2.2993 - val_loss: 10.7755 - val_rec_loss: 19.2674 - val_kl_loss: 2.2835
# Epoch 104/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 10.9499 - rec_loss: 19.6017 - kl_loss: 2.2980 - val_loss: 10.7593 - val_rec_loss: 19.2141 - val_kl_loss: 2.3045
# loss improved from:  10.767174955256673  to:  10.759251198186487 saving models
# Epoch 105/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 10.9480 - rec_loss: 19.5992 - kl_loss: 2.2968 - val_loss: 10.7959 - val_rec_loss: 19.3340 - val_kl_loss: 2.2577
# Epoch 106/200
# 227845/227845 [==============================] - 11s 46us/step - loss: 10.9490 - rec_loss: 19.5981 - kl_loss: 2.2999 - val_loss: 10.7818 - val_rec_loss: 19.2517 - val_kl_loss: 2.3118
# Epoch 107/200
# 227845/227845 [==============================] - 13s 56us/step - loss: 10.9466 - rec_loss: 19.5919 - kl_loss: 2.3013 - val_loss: 10.7542 - val_rec_loss: 19.2413 - val_kl_loss: 2.2671
# loss improved from:  10.759251198186487  to:  10.75419854876709 saving models
# Epoch 108/200
# 227845/227845 [==============================] - 11s 46us/step - loss: 10.9432 - rec_loss: 19.5894 - kl_loss: 2.2970 - val_loss: 10.7613 - val_rec_loss: 19.2217 - val_kl_loss: 2.3008
# Epoch 109/200
# 227845/227845 [==============================] - 11s 50us/step - loss: 10.9475 - rec_loss: 19.5909 - kl_loss: 2.3041 - val_loss: 10.7890 - val_rec_loss: 19.2914 - val_kl_loss: 2.2866
# Epoch 110/200
# 227845/227845 [==============================] - 11s 50us/step - loss: 10.9465 - rec_loss: 19.5894 - kl_loss: 2.3037 - val_loss: 10.7886 - val_rec_loss: 19.2765 - val_kl_loss: 2.3008
# Epoch 111/200
# 227845/227845 [==============================] - 13s 55us/step - loss: 10.9454 - rec_loss: 19.5852 - kl_loss: 2.3055 - val_loss: 10.7569 - val_rec_loss: 19.2127 - val_kl_loss: 2.3011
# Epoch 112/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 10.9402 - rec_loss: 19.5782 - kl_loss: 2.3023 - val_loss: 10.7633 - val_rec_loss: 19.2155 - val_kl_loss: 2.3111
# Epoch 113/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 10.9435 - rec_loss: 19.5822 - kl_loss: 2.3049 - val_loss: 10.7574 - val_rec_loss: 19.2414 - val_kl_loss: 2.2733
# Epoch 114/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 10.9491 - rec_loss: 19.5857 - kl_loss: 2.3126 - val_loss: 10.7748 - val_rec_loss: 19.2517 - val_kl_loss: 2.2979
# Epoch 115/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 10.9439 - rec_loss: 19.5827 - kl_loss: 2.3051 - val_loss: 10.7677 - val_rec_loss: 19.2421 - val_kl_loss: 2.2934
# Epoch 116/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 10.9427 - rec_loss: 19.5784 - kl_loss: 2.3070 - val_loss: 10.7681 - val_rec_loss: 19.2315 - val_kl_loss: 2.3048
# Epoch 117/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 10.9388 - rec_loss: 19.5784 - kl_loss: 2.2991 - val_loss: 10.7906 - val_rec_loss: 19.2849 - val_kl_loss: 2.2963
# Epoch 118/200
# 227845/227845 [==============================] - 11s 50us/step - loss: 10.9408 - rec_loss: 19.5773 - kl_loss: 2.3043 - val_loss: 10.7385 - val_rec_loss: 19.1656 - val_kl_loss: 2.3114
# loss improved from:  10.75419854876709  to:  10.738469044682786 saving models
# Epoch 119/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 10.9401 - rec_loss: 19.5761 - kl_loss: 2.3040 - val_loss: 10.7568 - val_rec_loss: 19.1883 - val_kl_loss: 2.3253
# Epoch 120/200
# 227845/227845 [==============================] - 10s 45us/step - loss: 10.9411 - rec_loss: 19.5742 - kl_loss: 2.3081 - val_loss: 10.7555 - val_rec_loss: 19.1983 - val_kl_loss: 2.3127
# Epoch 121/200
# 227845/227845 [==============================] - 10s 46us/step - loss: 10.9414 - rec_loss: 19.5719 - kl_loss: 2.3109 - val_loss: 10.7566 - val_rec_loss: 19.2199 - val_kl_loss: 2.2934
# Epoch 122/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 10.9423 - rec_loss: 19.5768 - kl_loss: 2.3079 - val_loss: 10.7649 - val_rec_loss: 19.2328 - val_kl_loss: 2.2970
# Epoch 123/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 10.9216 - rec_loss: 19.5403 - kl_loss: 2.3030 - val_loss: 10.7496 - val_rec_loss: 19.2028 - val_kl_loss: 2.2964
# Epoch 124/200
# 227845/227845 [==============================] - 10s 45us/step - loss: 10.9203 - rec_loss: 19.5413 - kl_loss: 2.2993 - val_loss: 10.7502 - val_rec_loss: 19.2002 - val_kl_loss: 2.3001
# Epoch 125/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 10.9206 - rec_loss: 19.5370 - kl_loss: 2.3043 - val_loss: 10.7527 - val_rec_loss: 19.2098 - val_kl_loss: 2.2955
# Epoch 126/200
# 227845/227845 [==============================] - 10s 46us/step - loss: 10.9243 - rec_loss: 19.5448 - kl_loss: 2.3038 - val_loss: 10.7507 - val_rec_loss: 19.1955 - val_kl_loss: 2.3058
# Epoch 127/200
# 227845/227845 [==============================] - 11s 46us/step - loss: 10.9211 - rec_loss: 19.5337 - kl_loss: 2.3085 - val_loss: 10.7494 - val_rec_loss: 19.2061 - val_kl_loss: 2.2927
# Epoch 128/200
# 227845/227845 [==============================] - 11s 46us/step - loss: 10.9167 - rec_loss: 19.5276 - kl_loss: 2.3057 - val_loss: 10.7517 - val_rec_loss: 19.2145 - val_kl_loss: 2.2889
# Epoch 129/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 10.9182 - rec_loss: 19.5350 - kl_loss: 2.3014 - val_loss: 10.7481 - val_rec_loss: 19.1928 - val_kl_loss: 2.3033
# Epoch 130/200
# 227845/227845 [==============================] - 11s 46us/step - loss: 10.9190 - rec_loss: 19.5343 - kl_loss: 2.3037 - val_loss: 10.7527 - val_rec_loss: 19.1999 - val_kl_loss: 2.3055
# Epoch 131/200
# 227845/227845 [==============================] - 10s 46us/step - loss: 10.9227 - rec_loss: 19.5371 - kl_loss: 2.3084 - val_loss: 10.7473 - val_rec_loss: 19.1888 - val_kl_loss: 2.3058
# Epoch 132/200
# 227845/227845 [==============================] - 11s 46us/step - loss: 10.9208 - rec_loss: 19.5328 - kl_loss: 2.3087 - val_loss: 10.7450 - val_rec_loss: 19.2047 - val_kl_loss: 2.2852
# Epoch 133/200
# 227845/227845 [==============================] - 10s 46us/step - loss: 10.9209 - rec_loss: 19.5351 - kl_loss: 2.3067 - val_loss: 10.7431 - val_rec_loss: 19.1761 - val_kl_loss: 2.3101
# Epoch 134/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 10.9139 - rec_loss: 19.5238 - kl_loss: 2.3040 - val_loss: 10.7450 - val_rec_loss: 19.1869 - val_kl_loss: 2.3032
# Epoch 135/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 10.9170 - rec_loss: 19.5305 - kl_loss: 2.3035 - val_loss: 10.7428 - val_rec_loss: 19.1795 - val_kl_loss: 2.3061
# Epoch 136/200
# 227845/227845 [==============================] - 11s 50us/step - loss: 10.9157 - rec_loss: 19.5236 - kl_loss: 2.3078 - val_loss: 10.7430 - val_rec_loss: 19.1815 - val_kl_loss: 2.3045
# Epoch 137/200
# 227845/227845 [==============================] - 12s 51us/step - loss: 10.9121 - rec_loss: 19.5195 - kl_loss: 2.3047 - val_loss: 10.7430 - val_rec_loss: 19.1818 - val_kl_loss: 2.3042
# Epoch 138/200
# 227845/227845 [==============================] - 12s 52us/step - loss: 10.9149 - rec_loss: 19.5269 - kl_loss: 2.3030 - val_loss: 10.7360 - val_rec_loss: 19.1682 - val_kl_loss: 2.3037
# loss improved from:  10.738469044682786  to:  10.735952670108501 saving models
# Epoch 139/200
# 227845/227845 [==============================] - 12s 53us/step - loss: 10.9151 - rec_loss: 19.5270 - kl_loss: 2.3032 - val_loss: 10.7477 - val_rec_loss: 19.1925 - val_kl_loss: 2.3029
# Epoch 140/200
# 227845/227845 [==============================] - 11s 50us/step - loss: 10.9180 - rec_loss: 19.5315 - kl_loss: 2.3045 - val_loss: 10.7447 - val_rec_loss: 19.1859 - val_kl_loss: 2.3035
# Epoch 141/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 10.9125 - rec_loss: 19.5235 - kl_loss: 2.3014 - val_loss: 10.7460 - val_rec_loss: 19.1975 - val_kl_loss: 2.2945
# Epoch 142/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 10.9170 - rec_loss: 19.5318 - kl_loss: 2.3023 - val_loss: 10.7440 - val_rec_loss: 19.1827 - val_kl_loss: 2.3053
# Epoch 143/200
# 227845/227845 [==============================] - 11s 50us/step - loss: 10.9179 - rec_loss: 19.5288 - kl_loss: 2.3070 - val_loss: 10.7386 - val_rec_loss: 19.1714 - val_kl_loss: 2.3058
# Epoch 144/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 10.9150 - rec_loss: 19.5260 - kl_loss: 2.3040 - val_loss: 10.7494 - val_rec_loss: 19.1955 - val_kl_loss: 2.3033
# Epoch 145/200
# 227845/227845 [==============================] - 11s 49us/step - loss: 10.9176 - rec_loss: 19.5305 - kl_loss: 2.3046 - val_loss: 10.7428 - val_rec_loss: 19.1829 - val_kl_loss: 2.3028
# Epoch 146/200
# 227845/227845 [==============================] - 11s 48us/step - loss: 10.9149 - rec_loss: 19.5264 - kl_loss: 2.3034 - val_loss: 10.7433 - val_rec_loss: 19.1836 - val_kl_loss: 2.3031
# Epoch 147/200
# 227845/227845 [==============================] - 11s 46us/step - loss: 10.9118 - rec_loss: 19.5204 - kl_loss: 2.3033 - val_loss: 10.7463 - val_rec_loss: 19.1904 - val_kl_loss: 2.3021
# Epoch 148/200
# 227845/227845 [==============================] - 11s 47us/step - loss: 10.9156 - rec_loss: 19.5283 - kl_loss: 2.3028 - val_loss: 10.7362 - val_rec_loss: 19.1703 - val_kl_loss: 2.3021
# Epoch 149/200
# 227845/227845 [==============================] - 12s 51us/step - loss: 10.9163 - rec_loss: 19.5287 - kl_loss: 2.3038 - val_loss: 10.7504 - val_rec_loss: 19.1976 - val_kl_loss: 2.3031
# Epoch 150/200
# 227845/227845 [==============================] - 11s 46us/step - loss: 10.9132 - rec_loss: 19.5226 - kl_loss: 2.3037 - val_loss: 10.7408 - val_rec_loss: 19.1784 - val_kl_loss: 2.3033
# Epoch 151/200
# 227845/227845 [==============================] - 10s 44us/step - loss: 10.9169 - rec_loss: 19.5291 - kl_loss: 2.3048 - val_loss: 10.7476 - val_rec_loss: 19.1905 - val_kl_loss: 2.3046
# Epoch 152/200
# 227845/227845 [==============================] - 10s 44us/step - loss: 10.9149 - rec_loss: 19.5251 - kl_loss: 2.3047 - val_loss: 10.7467 - val_rec_loss: 19.1902 - val_kl_loss: 2.3033
# Epoch 153/200
# 227845/227845 [==============================] - 10s 44us/step - loss: 10.9162 - rec_loss: 19.5284 - kl_loss: 2.3041 - val_loss: 10.7534 - val_rec_loss: 19.2036 - val_kl_loss: 2.3033
# Epoch 154/200
# 227845/227845 [==============================] - 11s 46us/step - loss: 10.9204 - rec_loss: 19.5362 - kl_loss: 2.3045 - val_loss: 10.7386 - val_rec_loss: 19.1732 - val_kl_loss: 2.3040
# Epoch 155/200
# 227845/227845 [==============================] - 10s 45us/step - loss: 10.9147 - rec_loss: 19.5244 - kl_loss: 2.3049 - val_loss: 10.7366 - val_rec_loss: 19.1690 - val_kl_loss: 2.3042
# Epoch 156/200
# 227845/227845 [==============================] - 10s 45us/step - loss: 10.9128 - rec_loss: 19.5204 - kl_loss: 2.3052 - val_loss: 10.7465 - val_rec_loss: 19.1888 - val_kl_loss: 2.3042
# Epoch 157/200
# 227845/227845 [==============================] - 10s 45us/step - loss: 10.9142 - rec_loss: 19.5233 - kl_loss: 2.3051 - val_loss: 10.7501 - val_rec_loss: 19.1960 - val_kl_loss: 2.3042

# %% [markdown]
# Plotting training and validation loss:

# %%
#fig = plt.figure(figsize=(14, 6))
#ax = fig.gca()
#ax.plot(history.history['rec_loss']);
#ax.plot(history.history['val_rec_loss']);

# %%
def draw_history(history, metric):
    plt.plot(history.history[metric])
    plt.plot(history.history['val_'+ metric])
    plt.title('model '+metric)
    plt.ylabel(metric)
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
draw_history(history, 'loss')

# %% [markdown]
# Plotting the learned latent representations for normal and anomalous instances in the specified dataset (training/validation/test):

# %%
x_data = x_test
y_data = y_test

with_labels = np.concatenate([x_data, np.reshape(np.ravel(y_data), (-1, 1))], axis=1) #concatenate x and y to be able to filter by class

normal = with_labels[np.where(with_labels[:, -1] == 0)] #filter normal instances
anomalous = with_labels[np.where(with_labels[:, -1] == 1)] #filter anomalous instances

#normal_encoded = encoder.predict(normal[:, :-1], batch_size=128)
normal_encoded = encoder.predict(normal[:, :-1], batch_size=batch_size)
#anomalous_encoded = encoder.predict(anomalous[:, :-1], batch_size=128)
anomalous_encoded = encoder.predict(anomalous[:, :-1], batch_size=batch_size)

fig = plt.figure(figsize=(6, 6))
ax = fig.gca()

#semicolon at the end hides unnecessary output
ax.scatter(normal_encoded[:, 0], normal_encoded[:, 1]);
ax.scatter(anomalous_encoded[:, 0], anomalous_encoded[:, 1]);

# %% [markdown]
# Apply simple Linear Discriminant Analysis to learned features (the latent representations):

# %%
#with_labels_encoded = encoder.predict(with_labels[:, :-1], batch_size=128)
with_labels_encoded = encoder.predict(with_labels[:, :-1], batch_size=batch_size)

X = with_labels_encoded
y = with_labels[:, -1]

clf = LinearDiscriminantAnalysis()
clf.fit(X, y)

pred = clf.predict(X)

print("AUC(ROC): " + str(metrics.roc_auc_score(y, pred)))
print("Precision: " + str(metrics.precision_score(y, pred)))
print("Recall: " + str(metrics.recall_score(y, pred)))
print("F1 score: " + str(metrics.f1_score(y, pred)))

tn, fp, fn, tp = metrics.confusion_matrix(y, pred).ravel()

print("False positives: " + str(fp))
print("True positives: " + str(tp))
print("False negatives: " + str(fn))
print("True negatives: " + str(tn))
# Out:
# AUC(ROC): 0.8619899035866456
# Precision: 0.71
# Recall: 0.7244897959183674
# F1 score: 0.7171717171717172
# False positives: 29
# True positives: 71
# False negatives: 27
# True negatives: 56835

# %%
metrics.confusion_matrix(y, pred)
# Out:
# array([[56835,    29],
#        [   27,    71]], dtype=int64)

# %%
print (classification_report(y, pred, target_names=['class 0','class 1']))
acc = accuracy_score(y, pred)
Accuracy = acc*100
print('Accuracy =',Accuracy)
# Out:
#              precision    recall  f1-score   support
#
#     class 0       1.00      1.00      1.00     56864
#     class 1       0.71      0.72      0.72        98
#
# avg / total       1.00      1.00      1.00     56962
#
# Accuracy = 99.90168884519505

# %% [markdown]
# ### Reconstruction error
#
# We can see that distribution of reconstruction error is different bwtween Normal and Fraud cases, but the difference is not big enought to perform classification

# %%
x_train_encoded = encoder.predict(x_train)

pred_train = decoder.predict(x_train_encoded)
mse = np.mean(np.power(x_train - pred_train, 2), axis=1)
error_df = pd.DataFrame({'recon_error': mse, 'Class': y_train})

plt.figure(figsize=(10,6))
sns.kdeplot(error_df.recon_error[error_df.Class==0], label='normal', shade=True, clip=(0,10))
sns.kdeplot(error_df.recon_error[error_df.Class==1], label='fraud', shade=True, clip=(0,10))
plt.xlabel('reconstruction error');
plt.title('Reconstruction error - Train set')
# Out:
# Text(0.5,1,'Reconstruction error - Train set')

# %%
x_test_encoded = encoder.predict(x_test)

pred_test = decoder.predict(x_test_encoded)
mseT = np.mean(np.power(x_test - pred_test, 2), axis=1)
error_df = pd.DataFrame({'recon_error': mseT, 'Class': y_test})

plt.figure(figsize=(10,6))
sns.kdeplot(error_df.recon_error[error_df.Class==0], label='normal', shade=True, clip=(0,10))
sns.kdeplot(error_df.recon_error[error_df.Class==1], label='fraud', shade=True, clip=(0,10))
plt.xlabel('reconstruction error');

# %%
# this function returns a plot of Recall vs threshold/ Precision vs threshold with the point of intersection of two curves
def reconstruction(x_test, y_test):
    precision, recall, th = precision_recall_curve(error_df.Class, error_df.recon_error) # finding the precision, recall and threshold using  precision_recall_curve function
    plt.plot(th, precision[1:], 'b', label='Precision curve') # ploting the curve for Precision  
    plt.plot(th, recall[1:], 'r', label='Recall curve')       # plotting the curve for recall
    plt.title('Recall vs threshold/ Precision vs threshold ') # setting the title
    plt.xlabel('threshold')                                   # setting the x-label
    plt.ylabel('Precision/ Recall')                           # setting the y-label
    plt.legend()                                              # setting the legend
    
    idx = np.argwhere(np.diff((precision[1:] - recall[1:]) == 0))      # finding the index of the point of intersection of both the curves
    plt.plot(th[idx], precision[1:][idx],"yo", label = 'Intersection') # making a yellow dot on the point of intersection
    plt.show()                                                         
    return(th[idx], precision[1:][idx])

# %%
reconstruction(x_test, y_test)
# Out:
# (array([[ 16.99658527],
#         [129.90171859]]), array([[0.01639344],
#         [0.        ]]))

# %% [markdown]
# And see how well we're dividing the two types of transactions:

# %%
threshold = 2

groups = error_df.groupby('Class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.recon_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %% [markdown]
# ### Latent space
# * We can see that Fraud and Normal cases, can be separable at latent space.

# %%
x_train_encoded = encoder.predict(x_train)

plt.figure(figsize=(8, 6))
plt.scatter(x_train_encoded[:, 0], x_train_encoded[:, 1], c=y_train, alpha=0.3)
plt.title('Train set in latent space')
plt.show()

# %%
x_test_encoded = encoder.predict(x_test)

plt.figure(figsize=(8, 6))
plt.scatter(x_test_encoded[:, 0], x_test_encoded[:, 1], c=y_test, alpha=0.3)

plt.title('Test set in latent space')
plt.show()

# %% [markdown]
# ### Lest classify in Latent spacw
# * Any classification method can be used, lets try nearest neighbour
# * Playing with classification parameter to get best prediction on Validation set

# %% [markdown]
# #### More on K
# You’re probably wondering how to pick the variable K and what its effects are on your classifier. Well, like most machine learning algorithms, the K in KNN is a hyperparameter that you, as a designer, must pick in order to get the best possible fit for the data set. Intuitively, you can think of K as controlling the shape of the decision boundary we talked about earlier.
#
# When K is small, we are restraining the region of a given prediction and forcing our classifier to be “more blind” to the overall distribution. A small value for K provides the most flexible fit, which will have low bias but high variance. Graphically, our decision boundary will be more jagged.
#
# On the other hand, a higher K averages more voters in each prediction and hence is more resilient to outliers. Larger values of K will have smoother decision boundaries which means lower variance but increased bias.
#
# (If you want to learn more about the bias-variance tradeoff, check out Scott Roe’s Blog post. You can mess around with the value of K and watch the decision boundary change!)
#
# Reference: https://kevinzakka.github.io/2016/07/13/k-nearest-neighbor/

# %%
weights='uniform'
#n_neighbors=27
n_neighbors=5
clf = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)
X=x_test_encoded
y=y_test
clf.fit(X, y)

h=0.2
cmap_light = ListedColormap(['#FFAAAA', '#AAFFAA'])
cmap_bold = ListedColormap(['#FF0000', '#00FF00'])
# Plot the decision boundary. For that, we will assign a color to each
# point in the mesh [x_min, x_max]x[y_min, y_max].
x_min, x_max = X[:, 0].min() - 1, X[:, 0].max() + 1
y_min, y_max = X[:, 1].min() - 1, X[:, 1].max() + 1
xx, yy = np.meshgrid(np.arange(x_min, x_max, h), np.arange(y_min, y_max, h))
Z = clf.predict(np.c_[xx.ravel(), yy.ravel()])

# Put the result into a color plot
Z = Z.reshape(xx.shape)
plt.figure()
plt.pcolormesh(xx, yy, Z, cmap=cmap_light)

# Plot also the training points
plt.scatter(X[:, 0], X[:, 1], c=y, cmap=cmap_bold, edgecolor='k', s=20)
plt.xlim(xx.min(), xx.max())
plt.ylim(yy.min(), yy.max())
plt.title("2-Class classification (k = %i, weights = '%s')" % (n_neighbors, weights))
# Out:
# Text(0.5,1,"2-Class classification (k = 5, weights = 'uniform')")

# %% [markdown]
# ### Prediction on test set

# %%
def draw_roc_curve(y_true, y_pred):
    fpr, tpr, thresholds = roc_curve(y_true, y_pred)
    roc_auc = auc(fpr, tpr)

    plt.title('ROC Curve - Receiver Operating Characteristic')
    plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
    plt.legend(loc='lower right')
    plt.plot([0,1],[0,1],'g--')
    plt.xlim([-0.001, 1])
    plt.ylim([0, 1.001])
    plt.ylabel('True Positive Rate')
    plt.xlabel('False Positive Rate')
    plt.show();

# %%
def print_stats(ytest, ypred):
    
    print("Accuracy: {:.5f}, Cohen's Kappa Score: {:.5f}".format(
        accuracy_score(ytest, ypred), 
        cohen_kappa_score(ytest, ypred, weights="quadratic")))
    #ll = log_loss(ytest, ypred)
    #print("Log Loss: {}".format(ll))
    print(' ')
    print("Confusion Matrix:")
    print(confusion_matrix(ytest, ypred))
    print("Classification Report:")
    print(classification_report(ytest, ypred))

# %%
x_test_encoded = encoder.predict(x_test)

y_test_neighbour = clf.predict(x_test_encoded)
draw_roc_curve(y_test, y_test_neighbour)

print_stats(y_test, y_test_neighbour)
# Out:
# Accuracy: 0.99946, Cohen's Kappa Score: 0.83216
#
# Confusion Matrix:
# [[56854    10]
#  [   21    77]]
# Classification Report:
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     56864
#         1.0       0.89      0.79      0.83        98
#
# avg / total       1.00      1.00      1.00     56962

# %%
print('Total no. of Frauds in train data: ', y_train.value_counts()[1], 'out of ', y_train.count())
print('Total no. of Frauds in test data: ', y_test.value_counts()[1], 'out of ', y_test.count())
#print('Total no. of Frauds in test data: ', y_test.value_counts()[1], 'out of ', y_test.count())
# Out:
# Total no. of Frauds in train data:  394 out of  227845
# Total no. of Frauds in test data:  98 out of  56962

# %% [markdown]
# #### The results are not bad, lets try improve then by adding reconstruction error, to the classification

# %%
weights='uniform'
n_neighbors=5

clf = neighbors.KNeighborsClassifier(n_neighbors, weights=weights)

#X=np.concatenate((x_train_encoded, np.reshape(mse, (mse.shape[0],1))), axis=1)
X=np.concatenate((x_train_encoded, np.reshape(np.ravel(mse), (-1,1))), axis=1)

y=y_train

clf.fit(X, y)
x_test_encoded = encoder.predict(x_test)

#tests = np.concatenate((x_test_encoded, np.reshape(mseT, (mseT.shape[0],1))), axis=1)
tests = np.concatenate((x_test_encoded, np.reshape(np.ravel(mseT), (-1,1))), axis=1)

y_test_neighbour = clf.predict(tests)
draw_roc_curve(y_test, y_test_neighbour)

print_stats(y_test, y_test_neighbour)
# Out:
# Accuracy: 0.99940, Cohen's Kappa Score: 0.81691
#
# Confusion Matrix:
# [[56852    12]
#  [   22    76]]
# Classification Report:
#              precision    recall  f1-score   support
#
#         0.0       1.00      1.00      1.00     56864
#         1.0       0.86      0.78      0.82        98
#
# avg / total       1.00      1.00      1.00     56962

# %%
pfpr, ptpr, pthresholds = roc_curve(y_test, y_test_neighbour)
print (pthresholds)
# Out:
# [2. 1. 0.]
